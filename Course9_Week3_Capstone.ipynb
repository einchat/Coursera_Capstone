# %% [markdown]
# ## Notebook created for Capstone project

# %%
import numpy as np
import pandas as pd

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
webpage = requests.get(url)

# %%
webpage
# Out:
# <Response [200]>

# %%
# get the webpage data
data = webpage.text

# %%
soup= BeautifulSoup(data)
# Out:
# /home/jupyterlab/conda/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/jupyterlab/conda/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
# find table tag in the webpage data
# checked that the first table contains the necessary data
table = soup.find_all('table')[0]

# %%
df = pd.read_html(str(table)) #Read HTML tables into a list of DataFrame objects

# %%
df[0].head()
# Out:
#           0             1                 2
# 0  Postcode       Borough     Neighbourhood
# 1       M1A  Not assigned      Not assigned
# 2       M2A  Not assigned      Not assigned
# 3       M3A    North York         Parkwoods
# 4       M4A    North York  Victoria Village

# %%
Nbhd_df = df[0][1:]

# %%
Nbhd_df.head()
# Out:
#      0                 1                 2
# 1  M1A      Not assigned      Not assigned
# 2  M2A      Not assigned      Not assigned
# 3  M3A        North York         Parkwoods
# 4  M4A        North York  Victoria Village
# 5  M5A  Downtown Toronto      Harbourfront

# %%
Nbhd_df.columns = ['Postcode', 'Borough','Neighbourhood']

# %%
Nbhd_df.head(2)
# Out:
#   Postcode       Borough Neighbourhood
# 1      M1A  Not assigned  Not assigned
# 2      M2A  Not assigned  Not assigned

# %%
# checking for 'Not assigned' boroughs
Nbhd_df[Nbhd_df['Borough']=='Not assigned']
# Out:
#     Postcode       Borough Neighbourhood
# 1        M1A  Not assigned  Not assigned
# 2        M2A  Not assigned  Not assigned
# 10       M8A  Not assigned  Not assigned
# 14       M2B  Not assigned  Not assigned
# 21       M7B  Not assigned  Not assigned
# 22       M8B  Not assigned  Not assigned
# 31       M2C  Not assigned  Not assigned
# 37       M7C  Not assigned  Not assigned
# 38       M8C  Not assigned  Not assigned
# 46       M2E  Not assigned  Not assigned
# 47       M3E  Not assigned  Not assigned
# 51       M7E  Not assigned  Not assigned
# 52       M8E  Not assigned  Not assigned
# 53       M9E  Not assigned  Not assigned
# 55       M2G  Not assigned  Not assigned
# 56       M3G  Not assigned  Not assigned
# 60       M7G  Not assigned  Not assigned
# 61       M8G  Not assigned  Not assigned
# 62       M9G  Not assigned  Not assigned
# 74       M7H  Not assigned  Not assigned
# 75       M8H  Not assigned  Not assigned
# 76       M9H  Not assigned  Not assigned
# ...

# %%
Nbhd_df.shape
# Out:
# (289, 3)

# %%
Nbhd_df[Nbhd_df['Borough']=='Not assigned'].index
# Out:
# Int64Index([  1,   2,  10,  14,  21,  22,  31,  37,  38,  46,  47,  51,  52,
#              53,  55,  56,  60,  61,  62,  74,  75,  76,  89,  90,  91, 105,
#             106, 107, 121, 122, 137, 138, 149, 150, 156, 162, 163, 168, 176,
#             182, 183, 189, 190, 191, 195, 196, 202, 203, 204, 205, 210, 211,
#             224, 225, 239, 240, 243, 244, 249, 250, 255, 256, 260, 261, 262,
#             263, 265, 266, 276, 277, 278, 279, 280, 281, 282, 283, 289],
#            dtype='int64')

# %%
# droping these line items as per instruction
Nbhd_df.drop( Nbhd_df[Nbhd_df['Borough']=='Not assigned'].index, axis=0, inplace=True)
# Out:
# /home/jupyterlab/conda/lib/python3.6/site-packages/pandas/core/frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
Nbhd_df.shape
# Out:
# (212, 3)

# %%
Nbhd_df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 3      M3A        North York         Parkwoods
# 4      M4A        North York  Victoria Village
# 5      M5A  Downtown Toronto      Harbourfront
# 6      M5A  Downtown Toronto       Regent Park
# 7      M6A        North York  Lawrence Heights

# %%
# checking for 'Not assigned' neighborhoods
Nbhd_df[Nbhd_df['Neighbourhood']=='Not assigned']
# Out:
#   Postcode       Borough Neighbourhood
# 9      M7A  Queen's Park  Not assigned

# %%
# only 1 such case, manually assigning the value
Nbhd_df.loc[9,'Neighbourhood']= Nbhd_df.loc[9,'Borough']
# Out:
# /home/jupyterlab/conda/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /home/jupyterlab/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# verifying
Nbhd_df[Nbhd_df['Neighbourhood']=='Not assigned']
# Out:
# Empty DataFrame
# Columns: [Postcode, Borough, Neighbourhood]
# Index: []

# %%
Nbhd_df.groupby('Postcode').count()
# Out:
#           Borough  Neighbourhood
# Postcode
# M1B             2              2
# M1C             3              3
# M1E             3              3
# M1G             1              1
# M1H             1              1
# M1J             1              1
# M1K             3              3
# M1L             3              3
# M1M             3              3
# M1N             2              2
# M1P             3              3
# M1R             2              2
# M1S             1              1
# M1T             3              3
# M1V             4              4
# M1W             2              2
# M1X             1              1
# M2H             1              1
# M2J             3              3
# M2K             1              1
# M2L             2              2
# M2M             2              2
# M2N             1              1
# M2P             1              1
# M2R             1              1
# M3A             1              1
# M3B             1              1
# ...

# %%
# lamda function to concatenate the neighborhoods with comma as separator
Nbhd_group= pd.DataFrame(Nbhd_df.groupby('Postcode')['Neighbourhood'].apply(lambda x:  ', '.join(x)))

# %%
Nbhd_group.head()
# Out:
#                                    Neighbourhood
# Postcode
# M1B                               Rouge, Malvern
# M1C       Highland Creek, Rouge Hill, Port Union
# M1E            Guildwood, Morningside, West Hill
# M1G                                       Woburn
# M1H                                    Cedarbrae

# %%
Nbhd_group.reset_index(inplace=True)

# %%
Nbhd_group.head()
# Out:
#   Postcode                           Neighbourhood
# 0      M1B                          Rouge, Malvern
# 1      M1C  Highland Creek, Rouge Hill, Port Union
# 2      M1E       Guildwood, Morningside, West Hill
# 3      M1G                                  Woburn
# 4      M1H                               Cedarbrae

# %%
Nbhd_df.reset_index(inplace=True)

# %%
Nbhd_df.drop(['index'], axis=1, inplace=True)
# Out:
# /home/jupyterlab/conda/lib/python3.6/site-packages/pandas/core/frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
Nbhd_df.head(2)
# Out:
#   Postcode     Borough     Neighbourhood
# 0      M3A  North York         Parkwoods
# 1      M4A  North York  Victoria Village

# %%
# merge in order to get the borough data
Nbhd_group= Nbhd_group.merge(Nbhd_df, on='Postcode')

# %%
Nbhd_group.head()
# Out:
#   Postcode                         Neighbourhood_x      Borough  \
# 0      M1B                          Rouge, Malvern  Scarborough
# 1      M1B                          Rouge, Malvern  Scarborough
# 2      M1C  Highland Creek, Rouge Hill, Port Union  Scarborough
# 3      M1C  Highland Creek, Rouge Hill, Port Union  Scarborough
# 4      M1C  Highland Creek, Rouge Hill, Port Union  Scarborough
#
#   Neighbourhood_y
# 0           Rouge
# 1         Malvern
# 2  Highland Creek
# 3      Rouge Hill
# 4      Port Union

# %%
Nbhd_group.drop(['Neighbourhood_y'], axis=1, inplace=True)

# %%
Nbhd_group.drop_duplicates(inplace=True)

# %%
Nbhd_group.head()
# Out:
#   Postcode                         Neighbourhood_x      Borough
# 0      M1B                          Rouge, Malvern  Scarborough
# 2      M1C  Highland Creek, Rouge Hill, Port Union  Scarborough
# 5      M1E       Guildwood, Morningside, West Hill  Scarborough
# 8      M1G                                  Woburn  Scarborough
# 9      M1H                               Cedarbrae  Scarborough

# %%
Nbhd_group.shape
# Out:
# (103, 3)

# %%
Nbhd_group = Nbhd_group[['Postcode','Borough','Neighbourhood_x']]

# %%
Nbhd_group.head(2)
# Out:
#   Postcode      Borough                         Neighbourhood_x
# 0      M1B  Scarborough                          Rouge, Malvern
# 2      M1C  Scarborough  Highland Creek, Rouge Hill, Port Union

# %%
Nbhd_group.columns = ['Postcode','Borough','Neighbourhood']

# %%
Nbhd_group.head(2)
# Out:
#   Postcode      Borough                           Neighbourhood
# 0      M1B  Scarborough                          Rouge, Malvern
# 2      M1C  Scarborough  Highland Creek, Rouge Hill, Port Union

# %%
geo_df= pd.read_csv('http://cocl.us/Geospatial_data')

# %%
geo_df.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
geo_df.shape
# Out:
# (103, 3)

# %%
geo_df.columns = ['Postcode', 'Latitude','Longitude']

# %%
geo_df.head()
# Out:
#   Postcode   Latitude  Longitude
# 0      M1B  43.806686 -79.194353
# 1      M1C  43.784535 -79.160497
# 2      M1E  43.763573 -79.188711
# 3      M1G  43.770992 -79.216917
# 4      M1H  43.773136 -79.239476

# %%
Nbhd_group= Nbhd_group.merge(geo_df, on='Postcode')

# %%
Nbhd_group.head()
# Out:
#   Postcode      Borough                           Neighbourhood   Latitude  \
# 0      M1B  Scarborough                          Rouge, Malvern  43.806686
# 1      M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.784535
# 2      M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3      M1G  Scarborough                                  Woburn  43.770992
# 4      M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476
